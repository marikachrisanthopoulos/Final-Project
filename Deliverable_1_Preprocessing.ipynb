# %% [markdown]
# ## Preprocessing Data for Final Prokect

# %%
# Import dependencies/libraries
import pandas as pd

# %%
# Load in the data
file_path = "ShelterDogs.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#       ID            name   age     sex               breed  date_found  \
# 0  23807            Gida  0.25  female         Unknown Mix  2019-12-10
# 1    533  Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 2  23793             NaN  4.00    male         Unknown Mix  2019-12-08
# 3  23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
#
#   adoptable_from      posted            color    coat    size neutered  \
# 0     2019-12-11  2019-12-11              red   short   small       no
# 1     2019-12-01  2019-12-09  black and white   short   small       no
# 2     2019-12-23  2019-12-08      saddle back   short  medium       no
# 3     2019-12-23  2019-12-08     yellow-brown  medium  medium       no
# 4     2019-12-11  2019-12-11            black   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 0         NaN          NaN            NaN             NaN               NaN
# 1         NaN          yes            yes             yes               yes
# 2         NaN          NaN            NaN             NaN               NaN
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
#
#   get_along_cats keep_in
# 0            NaN     NaN
# 1            yes     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %%
# View the columns
df.columns
# Out:
# Index(['ID', 'name', 'age', 'sex', 'breed', 'date_found', 'adoptable_from',
#        'posted', 'color', 'coat', 'size', 'neutered', 'housebroken',
#        'likes_people', 'likes_children', 'get_along_males',
#        'get_along_females', 'get_along_cats', 'keep_in'],
#       dtype='object')

# %%
# View the data types
df.dtypes
# Out:
# ID                     int64
# name                  object
# age                  float64
# sex                   object
# breed                 object
# date_found            object
# adoptable_from        object
# posted                object
# color                 object
# coat                  object
# size                  object
# neutered              object
# housebroken           object
# likes_people          object
# likes_children        object
# get_along_males       object
# get_along_females     object
# get_along_cats        object
# keep_in               object
# dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column ID has 0 null values
# Column name has 92 null values
# Column age has 0 null values
# Column sex has 0 null values
# Column breed has 0 null values
# Column date_found has 0 null values
# Column adoptable_from has 0 null values
# Column posted has 0 null values
# Column color has 0 null values
# Column coat has 0 null values
# Column size has 0 null values
# Column neutered has 1085 null values
# Column housebroken has 2477 null values
# Column likes_people has 938 null values
# Column likes_children has 1718 null values
# Column get_along_males has 1304 null values
# Column get_along_females has 1264 null values
# Column get_along_cats has 2506 null values
# Column keep_in has 1021 null values

# %%
# Drop columns
# Unnecessary columns: ID, name, adoptable_from, posted
# Columns with too much missing data: neutered, housebroken, likes_children, get_along_males, get_along_females, get_along_cats, keep_in
updated_df = df.drop(["ID", "name", "adoptable_from", "color", "posted","neutered", "housebroken", "likes_children", "get_along_males", "get_along_females", "get_along_cats", "keep_in"], axis=1)
updated_df
# Out:
#         age     sex                           breed  date_found    coat  \
# 0      0.25  female                     Unknown Mix  2019-12-10   short
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 2      4.00    male                     Unknown Mix  2019-12-08   short
# 3      1.00    male                     Unknown Mix  2019-12-08  medium
# 4      2.00  female              French Bulldog Mix  2019-12-10   short
# ...     ...     ...                             ...         ...     ...
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2933  17.33  female       Staffordshire Terrier Mix  2004-08-27   short
# 2934  18.17    male                     Unknown Mix  2005-09-21   short
# 2935  17.17    male                     Unknown Mix  2004-11-27  medium
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people
# 0      small          NaN
# 1      small          yes
# 2     medium          NaN
# 3     medium          NaN
# 4      small          NaN
# ...      ...          ...
# 2932  medium          yes
# 2933   large          NaN
# 2934  medium          NaN
# 2935  medium          NaN
# 2936  medium          yes
#
# [2937 rows x 7 columns]

# %%
# View the data types of the remaining columns in the updated DF
updated_df.dtypes
# Out:
# age             float64
# sex              object
# breed            object
# date_found       object
# coat             object
# size             object
# likes_people     object
# dtype: object

# %%
# Drop null rows
updated_df = updated_df.dropna()
updated_df
# Out:
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people
# 1      small          yes
# 6      small          yes
# 9      small          yes
# 13     small          yes
# 14    medium          yes
# ...      ...          ...
# 2919   large          yes
# 2925  medium          yes
# 2928  medium          yes
# 2932  medium          yes
# 2936  medium          yes
#
# [1999 rows x 7 columns]

# %%
# Transform non-numerical columns to numerical types

# Sex column
def change_sex(sex):
    if sex == "male":
        return 0
    else:
        return 1
    
updated_df["sex_new"] = updated_df["sex"].apply(change_sex)
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people  sex_new
# 1      small          yes        1
# 6      small          yes        0
# 9      small          yes        1
# 13     small          yes        0
# 14    medium          yes        0
# ...      ...          ...      ...
# 2919   large          yes        1
# 2925  medium          yes        0
# 2928  medium          yes        0
# 2932  medium          yes        0
# 2936  medium          yes        0
#
# [1999 rows x 8 columns]

# %%
# Breed
def change_breed(breed):
    if breed == "Unknown Mix":
        return 0
    else:
        return 1

updated_df["breed_new"] = updated_df["breed"].apply(change_breed)
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people  sex_new  breed_new
# 1      small          yes        1          0
# 6      small          yes        0          0
# 9      small          yes        1          0
# 13     small          yes        0          0
# 14    medium          yes        0          1
# ...      ...          ...      ...        ...
# 2919   large          yes        1          1
# 2925  medium          yes        0          1
# 2928  medium          yes        0          1
# 2932  medium          yes        0          0
# 2936  medium          yes        0          1
#
# [1999 rows x 9 columns]

# %%
# likes_people
def change_likes_people(likes_people):
    if likes_people == "yes":
        return 0
    else:
        return 1

updated_df["likes_people_new"] = updated_df["likes_people"].apply(change_likes_people)
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people  sex_new  breed_new  likes_people_new
# 1      small          yes        1          0                 0
# 6      small          yes        0          0                 0
# 9      small          yes        1          0                 0
# 13     small          yes        0          0                 0
# 14    medium          yes        0          1                 0
# ...      ...          ...      ...        ...               ...
# 2919   large          yes        1          1                 0
# 2925  medium          yes        0          1                 0
# 2928  medium          yes        0          1                 0
# 2932  medium          yes        0          0                 0
# 2936  medium          yes        0          1                 0
#
# [1999 rows x 10 columns]

# %%
# coat
def change_coat(coat):
    if coat == "short":
        return 0
    elif coat == "medium":
        return 1
    elif coat == "long":
        return 2
    else:
        return 3

updated_df["coat_new"] = updated_df["coat"].apply(change_coat)
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people  sex_new  breed_new  likes_people_new  coat_new
# 1      small          yes        1          0                 0         0
# 6      small          yes        0          0                 0         0
# 9      small          yes        1          0                 0         0
# 13     small          yes        0          0                 0         0
# 14    medium          yes        0          1                 0         0
# ...      ...          ...      ...        ...               ...       ...
# 2919   large          yes        1          1                 0         1
# 2925  medium          yes        0          1                 0         0
# 2928  medium          yes        0          1                 0         1
# 2932  medium          yes        0          0                 0         0
# 2936  medium          yes        0          1                 0         0
#
# [1999 rows x 11 columns]

# %%
# size
def change_size(size):
    if size == "small":
        return 0
    elif size == "medium":
        return 1
    elif size == "large":
        return 2
    else:
        return "N/A"
    
updated_df["size_new"] = updated_df["size"].apply(change_size)
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#         age     sex                           breed  date_found    coat  \
# 1      0.17  female                     Unknown Mix  2019-12-01   short
# 6      0.17    male                     Unknown Mix  2019-12-01   short
# 9      0.17  female                     Unknown Mix  2019-12-10   short
# 13     0.17    male                     Unknown Mix  2019-12-10   short
# 14     1.50    male     Bull Terrier, Dachshund Mix  2019-12-01   short
# ...     ...     ...                             ...         ...     ...
# 2919  15.67  female                          Kuvasz  2005-04-01  medium
# 2925  13.75    male         German Shepherd Dog Mix  2006-06-01   short
# 2928  13.75    male                        Pumi Mix  2007-01-15  medium
# 2932  16.92    male                     Unknown Mix  2003-12-25   short
# 2936  16.08    male  German Shepherd Dog, Hound Mix  2005-04-02   short
#
#         size likes_people  sex_new  breed_new  likes_people_new  coat_new  \
# 1      small          yes        1          0                 0         0
# 6      small          yes        0          0                 0         0
# 9      small          yes        1          0                 0         0
# 13     small          yes        0          0                 0         0
# 14    medium          yes        0          1                 0         0
# ...      ...          ...      ...        ...               ...       ...
# 2919   large          yes        1          1                 0         1
# 2925  medium          yes        0          1                 0         0
# 2928  medium          yes        0          1                 0         1
# 2932  medium          yes        0          0                 0         0
# 2936  medium          yes        0          1                 0         0
#
#       size_new
# 1            0
# 6            0
# 9            0
# 13           0
# 14           1
# ...        ...
# 2919         2
# 2925         1
# 2928         1
# 2932         1
# 2936         1
#
# [1999 rows x 12 columns]

# %%
# date
# Split data based on y, m, d
updated_dates = updated_df["date_found"].str.split(pat = "-", expand=True)
updated_dates
# Out:
#          0   1   2
# 1     2019  12  01
# 6     2019  12  01
# 9     2019  12  10
# 13    2019  12  10
# 14    2019  12  01
# ...    ...  ..  ..
# 2919  2005  04  01
# 2925  2006  06  01
# 2928  2007  01  15
# 2932  2003  12  25
# 2936  2005  04  02
#
# [1999 rows x 3 columns]

# %%
# Insert month column to updated_df
updated_df["month_found_new"] = updated_dates[1]

# Drop old date_found column
updated_df = updated_df.drop(["date_found"], axis=1)

# View updated DF
updated_df
# Out:
# /Users/marika.chrisanthopoulos/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         age     sex                           breed    coat    size  \
# 1      0.17  female                     Unknown Mix   short   small
# 6      0.17    male                     Unknown Mix   short   small
# 9      0.17  female                     Unknown Mix   short   small
# 13     0.17    male                     Unknown Mix   short   small
# 14     1.50    male     Bull Terrier, Dachshund Mix   short  medium
# ...     ...     ...                             ...     ...     ...
# 2919  15.67  female                          Kuvasz  medium   large
# 2925  13.75    male         German Shepherd Dog Mix   short  medium
# 2928  13.75    male                        Pumi Mix  medium  medium
# 2932  16.92    male                     Unknown Mix   short  medium
# 2936  16.08    male  German Shepherd Dog, Hound Mix   short  medium
#
#      likes_people  sex_new  breed_new  likes_people_new  coat_new  size_new  \
# 1             yes        1          0                 0         0         0
# 6             yes        0          0                 0         0         0
# 9             yes        1          0                 0         0         0
# 13            yes        0          0                 0         0         0
# 14            yes        0          1                 0         0         1
# ...           ...      ...        ...               ...       ...       ...
# 2919          yes        1          1                 0         1         2
# 2925          yes        0          1                 0         0         1
# 2928          yes        0          1                 0         1         1
# 2932          yes        0          0                 0         0         1
# 2936          yes        0          1                 0         0         1
#
#      month_found_new
# 1                 12
# 6                 12
# 9                 12
# 13                12
# 14                12
# ...              ...
# 2919              04
# 2925              06
# 2928              01
# 2932              12
# 2936              04
#
# [1999 rows x 12 columns]

# %%
# View updated DF
updated_df
# Out:
#         age     sex                           breed    coat    size  \
# 1      0.17  female                     Unknown Mix   short   small
# 6      0.17    male                     Unknown Mix   short   small
# 9      0.17  female                     Unknown Mix   short   small
# 13     0.17    male                     Unknown Mix   short   small
# 14     1.50    male     Bull Terrier, Dachshund Mix   short  medium
# ...     ...     ...                             ...     ...     ...
# 2919  15.67  female                          Kuvasz  medium   large
# 2925  13.75    male         German Shepherd Dog Mix   short  medium
# 2928  13.75    male                        Pumi Mix  medium  medium
# 2932  16.92    male                     Unknown Mix   short  medium
# 2936  16.08    male  German Shepherd Dog, Hound Mix   short  medium
#
#      likes_people  sex_new  breed_new  likes_people_new  coat_new  size_new  \
# 1             yes        1          0                 0         0         0
# 6             yes        0          0                 0         0         0
# 9             yes        1          0                 0         0         0
# 13            yes        0          0                 0         0         0
# 14            yes        0          1                 0         0         1
# ...           ...      ...        ...               ...       ...       ...
# 2919          yes        1          1                 0         1         2
# 2925          yes        0          1                 0         0         1
# 2928          yes        0          1                 0         1         1
# 2932          yes        0          0                 0         0         1
# 2936          yes        0          1                 0         0         1
#
#      month_found_new
# 1                 12
# 6                 12
# 9                 12
# 13                12
# 14                12
# ...              ...
# 2919              04
# 2925              06
# 2928              01
# 2932              12
# 2936              04
#
# [1999 rows x 12 columns]

# %%
# Create Processed DF
processed_df = updated_df.drop(["sex", "breed", "coat", "size", "likes_people"], axis=1)

# View Processed DF
processed_df
# Out:
#         age  sex_new  breed_new  likes_people_new  coat_new  size_new  \
# 1      0.17        1          0                 0         0         0
# 6      0.17        0          0                 0         0         0
# 9      0.17        1          0                 0         0         0
# 13     0.17        0          0                 0         0         0
# 14     1.50        0          1                 0         0         1
# ...     ...      ...        ...               ...       ...       ...
# 2919  15.67        1          1                 0         1         2
# 2925  13.75        0          1                 0         0         1
# 2928  13.75        0          1                 0         1         1
# 2932  16.92        0          0                 0         0         1
# 2936  16.08        0          1                 0         0         1
#
#      month_found_new
# 1                 12
# 6                 12
# 9                 12
# 13                12
# 14                12
# ...              ...
# 2919              04
# 2925              06
# 2928              01
# 2932              12
# 2936              04
#
# [1999 rows x 7 columns]

# %%
# Export file
processed_df.to_csv("processed_data.csv", index=False)

# %%
# Create sample datasets
original_data = "ShelterDogs.csv"
original_df = pd.read_csv(original_data)

# Original and processed DF's
original_df
processed_df

# First 200 values of each dataset
original_sample_df = original_df.head(200)
processed_sample_df = processed_df.head(200)

# %%
# View original sample DF
original_sample_df
# Out:
#         ID            name    age     sex               breed  date_found  \
# 0    23807            Gida   0.25  female         Unknown Mix  2019-12-10
# 1      533  Frida És Ricsi   0.17  female         Unknown Mix  2019-12-01
# 2    23793             NaN   4.00    male         Unknown Mix  2019-12-08
# 3    23795             NaN   1.00    male         Unknown Mix  2019-12-08
# 4    23806             Amy   2.00  female  French Bulldog Mix  2019-12-10
# ..     ...             ...    ...     ...                 ...         ...
# 195   2858            Boni  11.17    male    Golden Retriever  2019-01-01
# 196   2862            Gray   6.17    male  Labrador Retriever  2019-02-21
# 197   2860          Bubuka   6.17    male  Labrador Retriever  2019-01-01
# 198   2854            Beni  11.17    male  Labrador Retriever  2019-01-01
# 199   2861             Erl   8.17    male  Labrador Retriever  2019-02-21
#
#     adoptable_from      posted            color    coat    size neutered  \
# 0       2019-12-11  2019-12-11              red   short   small       no
# 1       2019-12-01  2019-12-09  black and white   short   small       no
# 2       2019-12-23  2019-12-08      saddle back   short  medium       no
# 3       2019-12-23  2019-12-08     yellow-brown  medium  medium       no
# 4       2019-12-11  2019-12-11            black   short   small       no
# ..             ...         ...              ...     ...     ...      ...
# 195     2019-01-01  2019-10-11           golden   short   large      NaN
# 196     2019-02-21  2019-10-11           yellow   short   large      NaN
# 197     2019-01-01  2019-10-11            black   short   large      yes
# 198     2019-01-01  2019-10-11           yellow   short   large      NaN
# 199     2019-02-21  2019-10-11           yellow   short   large      NaN
#
#     housebroken likes_people likes_children get_along_males get_along_females  \
# 0           NaN          NaN            NaN             NaN               NaN
# 1           NaN          yes            yes             yes               yes
# 2           NaN          NaN            NaN             NaN               NaN
# 3           NaN          NaN            NaN             NaN               NaN
# 4           NaN          NaN            NaN             NaN               NaN
# ..          ...          ...            ...             ...               ...
# 195         NaN          NaN            NaN             NaN               NaN
# 196         NaN          NaN            NaN             NaN               NaN
# 197         NaN          NaN            NaN             NaN               NaN
# 198         NaN          NaN            NaN             NaN               NaN
# 199         NaN          NaN            NaN             NaN               NaN
#
#     get_along_cats keep_in
# 0              NaN     NaN
# 1              yes     NaN
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN     NaN
# ..             ...     ...
# 195            NaN     NaN
# 196            NaN     NaN
# 197            NaN     NaN
# 198            NaN     NaN
# 199            NaN     NaN
#
# [200 rows x 19 columns]

# %%
# Export original sample DF to .csv
original_sample_df.to_csv("original_sample.csv", index=False)

# %%
# View processed sample DF
processed_sample_df
# Out:
#       age  sex_new  breed_new  likes_people_new  coat_new  size_new  \
# 1    0.17        1          0                 0         0         0
# 6    0.17        0          0                 0         0         0
# 9    0.17        1          0                 0         0         0
# 13   0.17        0          0                 0         0         0
# 14   1.50        0          1                 0         0         1
# ..    ...      ...        ...               ...       ...       ...
# 300  1.50        0          1                 0         0         0
# 301  1.92        0          0                 0         0         1
# 302  0.83        0          0                 0         1         1
# 303  2.42        0          1                 0         0         1
# 304  2.50        1          0                 0         0         1
#
#     month_found_new
# 1                12
# 6                12
# 9                12
# 13               12
# 14               12
# ..              ...
# 300              06
# 301              03
# 302              05
# 303              06
# 304              06
#
# [200 rows x 7 columns]

# %%
# Export original sample DF to .csv
processed_sample_df.to_csv("processed_sample.csv", index=False)
